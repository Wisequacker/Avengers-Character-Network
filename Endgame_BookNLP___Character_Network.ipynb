# %% [markdown]
# # BookNLP Character Network — Make a Network for Character in Any Book

# %% [markdown]
# By [Melanie Walsh](https://melaniewalsh.org/), based on a notebook by [David Bamman](https://people.ischool.berkeley.edu/~dbamman/)
#
# [BookNLP](https://github.com/booknlp/booknlp) is a natural language processing tool developed by David Bamman. This tool can computationally identify characters, people, places, quotations, events, and  a lot more for book-length documents in English (support for other languages coming soon!). Most NLP tools do not work well on book-length documents, which makes BookNLP extremely useful.
#
# This Colab notebook, which is [based on a notebook](https://github.com/booknlp/booknlp/blob/main/examples/Read%20character%20file.ipynb) created by David Bamman, demonstrates how to create character network data for a book with BookNLP. The default book for this notebook is Virginia Woolf's *Mrs. Dalloway* (1925). However, you can substitue another URL in the "Pick Your Book" section to try BookNLP out on another book. BookNLP will take a few minutes to process a text, depending on how long it is.
#
# # 🚨 Before You Begin 🚨
#
# First, you need to sign into a Google account to use this notebook.
#
# Second, BookNLP will work best if you switch to using a GPU, or Graphical Processing Unit, for this notebook. To use a GPU in Google Colab, go to the menu at the top of the screen and select:
#
# `Runtime > Change runtime type > Hardware accelerator > GPU (Then slick "Save")`
#
# To run all the code in this notebook, you can select:
#
# `Runtime > Run all`
#
# If you want to save your own changes to this notebook, you'll need to save a copy.

# %% [markdown]
# # Pick Your Book

# %% [markdown]
# The default book for this notebook is Virginia Woolf's *Mrs. Dalloway*: https://gutenberg.net.au/ebooks02/0200991.txt. But you can find a .txt URL from [Project Gutenberg](https://www.gutenberg.org/ebooks/search/?sort_order=downloads) or GitHub or anywhere else and plug it in below:

# %%
# !wget "https://gutenberg.net.au/ebooks02/0200991.txt" -O my_book.txt
# Out:
# --2021-12-10 04:10:53--  https://gutenberg.net.au/ebooks02/0200991.txt
# Resolving gutenberg.net.au (gutenberg.net.au)... 43.229.63.241
# Connecting to gutenberg.net.au (gutenberg.net.au)|43.229.63.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 370280 (362K) [text/plain]
# Saving to: ‘my_book.txt’
#
# my_book.txt         100%[===================>] 361.60K   442KB/s    in 0.8s
#
# 2021-12-10 04:10:55 (442 KB/s) - ‘my_book.txt’ saved [370280/370280]

# %% [markdown]
# Then click `Runtime > Run All`

# %% [markdown]
# # Install and Import Packages

# %%
# !pip install booknlp
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: booknlp in /usr/local/lib/python3.7/dist-packages (1.0.7)
# Requirement already satisfied: tensorflow>=1.15 in /usr/local/lib/python3.7/dist-packages (from booknlp) (2.7.0)
# Requirement already satisfied: transformers>=4.11.3 in /usr/local/lib/python3.7/dist-packages (from booknlp) (4.13.0)
# Requirement already satisfied: spacy>=3 in /usr/local/lib/python3.7/dist-packages (from booknlp) (3.2.1)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from booknlp) (1.10.0+cu111)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.6.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.0.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.19.5)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.4.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (8.0.13)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.23.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.10.0.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3->booknlp) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3->booknlp) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3->booknlp) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (2021.10.8)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.42.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.13.3)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.37.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (12.0.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.22.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.12.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.4.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=1.15->booknlp) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.15->booknlp) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=1.15->booknlp) (4.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.15->booknlp) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.15->booknlp) (3.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (0.2.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (0.0.46)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy>=3->booknlp) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3->booknlp) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.11.3->booknlp) (1.1.0)
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 9.2 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.2.0) (3.2.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.23.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from booknlp.booknlp import BookNLP
import json
from collections import Counter
from pathlib import Path
import pandas as pd
pd.options.display.max_rows = 200
pd.options.display.max_colwidth = 100

# %% [markdown]
# # Set Up BookNLP

# %%
model_params = {
		"pipeline":"entity,quote,supersense,event,coref", 
		"model":"big", 
	}

booknlp= BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity,quote,supersense,event,coref', 'model': 'big'}
# --- startup: 19.740 seconds ---

# %% [markdown]
# # Run BookNLP

# %% [markdown]
# Before we apply BookNLP, let's check to make sure our text file has the right character encoding.
#
# If your text file has a character encoding that is not UTF-8 or ISO-8859-1, then you will need to uncomment the last two lines in the code cell below and manually enter the character encoding of the file before transforming it into a UTF-8 file.

# %%
# Check to see if text file opens with UTF-8 encoding
try:
    open("renamed_Endgame_Script.txt", encoding='utf-8').read()
except UnicodeDecodeError:
    try:
      # Check to see if file opens with ISO-8859-1 encoding and, if so, rewrite the file as UTF-8
      text = open("my_book.txt", encoding='ISO-8859-1').read()
      open('my_book.txt', mode='w', encoding='utf-8').write(text)
    except:
      print("Character encoding error: You need to uncomment the lines above and specify the character encoding for this text file")
 
# Open the file with the current encoding
#text = open("my_book.txt", encoding='Your Character Encoding Here').read()
# Rewrite the file as a UTF-8 file
#open('my_book.txt', mode='w', encoding='utf-8'.write(text)

# %% [markdown]
# Apply BookNLP

# %%
inputFile = "renamed_Endgame_Script.txt"
outputDir = "AvengersFilms_dir/"
idd="my_film"

booknlp.process(inputFile, outputDir, idd)
# Out:
# --- spacy: 9.644 seconds ---
# --- entities: 150.221 seconds ---
# --- quotes: 0.080 seconds ---
# --- attribution: 14.234 seconds ---
# --- name coref: 0.412 seconds ---
# --- coref: 200.872 seconds ---
# --- TOTAL (excl. startup): 376.079 seconds ---, 33116 words

# %% [markdown]
# # Get Character Data

# %% [markdown]
# Load character data

# %%
character_data = json.load(open("AvengersFilms_dir/my_film.book"))

# %% [markdown]
# Make a counter

# %%
def get_counter_from_dependency_list(dependency_list):
    
    counter = Counter()

    for token in dependency_list:
        term = token["w"]
        tokenGlobalIndex=token["i"]
        counter[term] += 1
    return counter

# %% [markdown]
# Loop through character data and pull out information, then transform it into a DataFrame

# %%
character_data["characters"]
# Out:
# [{'agent': [{'i': 382, 'w': 'do'},
#    {'i': 691, 'w': 'like'},
#    {'i': 934, 'w': 'know'},
#    {'i': 948, 'w': 'know'},
#    {'i': 962, 'w': 'hope'},
#    {'i': 1017, 'w': 'say'},
#    {'i': 1020, 'w': 'feeling'},
#    {'i': 1153, 'w': 'know'},
#    {'i': 1155, 'w': 'said'},
#    {'i': 1164, 'w': 'hoping'},
#    {'i': 1164, 'w': 'hoping'},
#    {'i': 1193, 'w': 'mean'},
#    {'i': 1215, 'w': 'lie'},
#    {'i': 1224, 'w': 'drift'},
#    {'i': 1229, 'w': 'think'},
#    {'i': 1522, 'w': 'lost'},
#    {'i': 1813, 'w': 'thought'},
#    {'i': 1874, 'w': 'fight'},
#    {'i': 1939, 'w': 'saw'},
#    {'i': 1948, 'w': 'had'},
#    {'i': 1962, 'w': 'dreaming'},
#    {'i': 1971, 'w': 'gon'},
#    {'i': 1988, 'w': 'needed'},
#    {'i': 2014, 'w': 'need'},
#    {'i': 2037, 'w': 'need'},
#    {'i': 2043, 'w': 'believe'},
#    {'i': 2045, 'w': 'remember'},
#    {'i': 2132, 'w': 'said'},
#    {'i': 2312, 'w': 'got'},
#    {'i': 2320, 'w': 'got'},
#    {'i': 2320, 'w': 'got'},
#    {'i': 2504, 'w': 'bring'},
#    {'i': 2511, 'w': 'come'},
#    {'i': 2610, 'w': 'know'},
#    {'i': 2628, 'w': 'tell'},
#    {'i': 2660, 'w': 'wanted'},
#    {'i': 2667, 'w': 'ask'},
#    {'i': 2878, 'w': 'mean'},
#    {'i': 3054, 'w': 'like'},
#    {'i': 3232, 'w': 'head'},
#    {'i': 3269, 'w': 'know'},
#    {'i': 3296, 'w': 'know'},
#    {'i': 3300, 'w': 'going'},
#    {'i': 3681, 'w': 'used'},
#    {'i': 3706, 'w': 'sits'},
#    {'i': 3733, 'w': 'has'},
#    {'i': 3775, 'w': 'treated'},
#    {'i': 3852, 'w': 'went'},
#    {'i': 3996, 'w': 'Went'},
#    {'i': 4018, 'w': 'sitting'},
#    {'i': 4027, 'w': 'know'},
#    {'i': 4039, 'w': 'talk'},
#    {'i': 4098, 'w': 'cried'},
#    {'i': 4107, 'w': 'seeing'},
#    {'i': 4122, 'w': 'did'},
#    {'i': 4128, 'w': 'took'},
#    {'i': 4135, 'w': 'know'},
#    {'i': 4139, 'w': 'gon'},
#    {'i': 4174, 'w': 'went'},
#    {'i': 4184, 'w': 'met'},
#    {'i': 5351, 'w': 'covering'},
#    {'i': 5601, 'w': 'mean'},
#    {'i': 5625, 'w': 'got'},
#    {'i': 5728, 'w': 'offer'},
#    {'i': 5735, 'w': 'seem'},
#    {'i': 5809, 'w': 'saw'},
#    {'i': 5817, 'w': 'coming'},
#    {'i': 5922, 'w': 'keep'},
#    {'i': 5945, 'w': 'move'},
#    {'i': 5974, 'w': 'used'},
#    {'i': 5982, 'w': 'got'},
#    {'i': 6013, 'w': 'trying'},
#    {'i': 6022, 'w': 'think'},
#    {'i': 6096, 'w': 'got'},
#    {'i': 6102, 'w': 'had'},
#    {'i': 6102, 'w': 'had'},
#    {'i': 6148, 'w': 'know'},
#    {'i': 6154, 'w': 'need'},
#    {'i': 6202, 'w': 'struggles'},
#    {'i': 6210, 'w': 'blurts'},
#    {'i': 6317, 'w': 'got'},
#    {'i': 6405, 'w': 'starving'},
#    {'i': 6409, 'w': 'strides'},
#    {'i': 6441, 'w': 'saying'},
#    {'i': 6478, 'w': 'stop'},
#    {'i': 6575, 'w': 'know'},
#    {'i': 6584, 'w': 'stop'},
#    {'i': 6616, 'w': 'get'},
#    {'i': 6818, 'w': 'making'},
#    {'i': 6858, 'w': 'give'},
#    {'i': 6912, 'w': 'found'},
#    {'i': 6945, 'w': 'buy'},
#    {'i': 7122, 'w': 'did'},
#    {'i': 7259, 'w': 'believe'},
#    {'i': 7272, 'w': 'miss'},
#    {'i': 7296, 'w': 'execute'},
#    {'i': 7302, 'w': 'believe'},
#    {'i': 11833, 'w': 'drops'},
#    {'i': 11849, 'w': 'think'},
#    {'i': 11872, 'w': 'know'},
#    {'i': 12700, 'w': 'give'},
#    {'i': 12722, 'w': 'want'},
#    {'i': 12851, 'w': 'got'},
#    {'i': 12944, 'w': 'give'},
#    {'i': 13313, 'w': 'do'},
#    {'i': 13377, 'w': 'ask'},
#    {'i': 13533, 'w': 'heard'},
#    {'i': 13639, 'w': 'know'},
#    {'i': 14153, 'w': 'substitute'},
#    {'i': 14175, 'w': 'have'},
#    {'i': 14182, 'w': 'know'},
#    {'i': 14476, 'w': 'had'},
#    {'i': 14510, 'w': 'got'},
#    {'i': 14548, 'w': 'dating'},
#    {'i': 14601, 'w': 'like'},
#    {'i': 14721, 'w': 'get'},
#    {'i': 15330, 'w': 'do'},
#    {'i': 15522, 'w': 'think'},
#    {'i': 15648, 'w': 'looking'},
#    {'i': 15737, 'w': 'asking'},
#    {'i': 15761, 'w': 'do'},
#    {'i': 15777, 'w': 'need'},
#    {'i': 15785, 'w': 'have'},
#    {'i': 15785, 'w': 'have'},
#    {'i': 15925, 'w': 'gon'},
#    {'i': 15935, 'w': 'holds'},
#    {'i': 15942, 'w': 'extract'},
#    {'i': 15990, 'w': 'see'},
#    {'i': 16079, 'w': 'do'},
#    {'i': 16085, 'w': 'do'},
#    {'i': 16098, 'w': 'come'},
#    {'i': 16127, 'w': 'think'},
#    {'i': 16130, 'w': 'having'},
#    {'i': 16133, 'w': 'having'},
#    {'i': 16191, 'w': 'lost'},
#    {'i': 16197, 'w': 'had'},
#    {'i': 16217, 'w': 'get'},
#    {'i': 16342, 'w': 'do'},
#    {'i': 16347, 'w': 'do'},
#    {'i': 16353, 'w': 'do'},
#    {'i': 16854, 'w': 'ask'},
#    {'i': 17008, 'w': 'dispatching'},
#    {'i': 17087, 'w': 'swear'},
#    {'i': 17091, 'w': 'make'},
#    {'i': 17191, 'w': 'know'},
#    {'i': 17201, 'w': 'know'},
#    {'i': 17344, 'w': 'approaching'},
#    {'i': 17364, 'w': 'have'},
#    {'i': 17414, 'w': 'forgot'},
#    {'i': 17461, 'w': 'think'},
#    {'i': 17640, 'w': 'mean'},
#    {'i': 17706, 'w': 'mean'},
#    {'i': 17949, 'w': 'got'},
#    {'i': 17979, 'w': 'see'},
#    {'i': 18049, 'w': 'thought'},
#    {'i': 18090, 'w': 'got'},
#    {'i': 18099, 'w': 'gon'},
#    {'i': 18117, 'w': 'understand'},
#    {'i': 18145, 'w': 'give'},
#    {'i': 18156, 'w': 'gon'},
#    {'i': 18277, 'w': 'got'},
#    {'i': 18318, 'w': 'had'},
#    {'i': 18338, 'w': 'going'},
#    {'i': 18351, 'w': 'ask'},
#    {'i': 18410, 'w': 'gon'},
#    {'i': 18461, 'w': 'gon'},
#    {'i': 18527, 'w': 'gon'},
#    {'i': 18580, 'w': 'need'},
#    {'i': 18590, 'w': 'know'},
#    {'i': 18600, 'w': 'saying'},
#    {'i': 18762, 'w': 'gon'},
#    {'i': 18832, 'w': 'try'},
#    {'i': 18838, 'w': 'have'},
#    {'i': 32290, 'w': 'tried'},
#    {'i': 32294, 'w': 'had'},
#    {'i': 32303, 'w': 'tried'},
#    {'i': 32316, 'w': 'miss'},
#    {'i': 32340, 'w': 'come'},
#    {'i': 32382, 'w': 'get'},
#    {'i': 32566, 'w': 'know'},
#    {'i': 32602, 'w': 'trying'},
#    {'i': 32618, 'w': 'said'},
#    {'i': 32622, 'w': 'trying'},
#    {'i': 32740, 'w': 'put'},
#    {'i': 32746, 'w': 'thought'},
#    {'i': 32751, 'w': 'try'},
#    {'i': 32816, 'w': 'have'},
#    {'i': 32916, 'w': 'do'},
#    {'i': 32974, 'w': 'think'}],
#   'count': 691,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.423,
#     'she/her': 0.276,
#     'they/them/their': 0.114,
#     'xe/xem/xyr/xir': 0.065,
#     'ze/zem/zir/hir': 0.122},
#    'max': 0.423,
#    'total': 75.608},
#   'id': 0,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 472, 'n': 'I'},
#     {'c': 112, 'n': 'me'},
#     {'c': 58, 'n': 'my'},
#     {'c': 13, 'n': 'you'},
#     {'c': 11, 'n': 'My'},
#     {'c': 5, 'n': 'he'},
#     {'c': 4, 'n': 'You'},
#     {'c': 4, 'n': 'He'},
#     {'c': 4, 'n': 'Me'},
#     {'c': 2, 'n': 'his'},
#     {'c': 1, 'n': 'himself'},
#     {'c': 1, 'n': 'His'},
#     {'c': 1, 'n': 'myself'},
#     {'c': 1, 'n': 'him'},
#     {'c': 1, 'n': "I'm"},
#     {'c': 1, 'n': 'MY'}],
#    'proper': []},
#   'mod': [{'i': 2437, 'w': 'fine'},
#    {'i': 3716, 'w': 'inevitable'},
#    {'i': 5997, 'w': 'better'},
#    {'i': 6198, 'w': 'fine'},
#    {'i': 6327, 'w': 'sorry'},
#    {'i': 7629, 'w': 'happy'},
#    {'i': 7817, 'w': 'eating'},
#    {'i': 7840, 'w': 'confused'},
#    {'i': 11165, 'w': 'good'},
#    {'i': 11169, 'w': 'good'},
#    {'i': 11494, 'w': 'fine'},
#    {'i': 11672, 'w': 'scared'},
#    {'i': 11898, 'w': 'fine'},
#    {'i': 12940, 'w': 'sorry'},
#    {'i': 13128, 'w': 'careful'},
#    {'i': 13146, 'w': 'careful'},
#    {'i': 13300, 'w': 'ready'},
#    {'i': 13309, 'w': 'game'},
#    {'i': 14314, 'w': 'sure'},
#    {'i': 15632, 'w': 'careful'},
#    {'i': 15726, 'w': 'afraid'},
#    {'i': 18370, 'w': 'sorry'},
#    {'i': 19329, 'w': 'sorry'},
#    {'i': 19367, 'w': 'sure'},
#    {'i': 20565, 'w': 'late'},
#    {'i': 20959, 'w': 'worthy'},
#    {'i': 21428, 'w': 'inevitable'},
#    {'i': 22364, 'w': 'sure'},
#    {'i': 22726, 'w': 'visitor'},
#    {'i': 22829, 'w': 'fine'},
#    {'i': 22988, 'w': 'confused'},
#    {'i': 24999, 'w': 'sorry'},
#    {'i': 25400, 'w': 'sorry'},
#    {'i': 25852, 'w': 'okay'},
#    {'i': 25856, 'w': 'okay'},
#    {'i': 27000, 'w': 'thankful'},
#    {'i': 27896, 'w': 'about'},
#    {'i': 30383, 'w': 'inevitable'},
#    {'i': 31840, 'w': 'sure'},
#    {'i': 32789, 'w': 'happy'}],
#   'patient': [{'i': 2641, 'w': 'perfect'},
#    {'i': 2925, 'w': 'have'},
#    {'i': 3691, 'w': 'killed'},
#    {'i': 4736, 'w': 'Excuse'},
#    {'i': 5406, 'w': 'see'},
#    {'i': 5851, 'w': 'tell'},
#    {'i': 6110, 'w': 'recognize'},
#    {'i': 6306, 'w': 'pull'},
#    {'i': 7359, 'w': 'telling'},
#    {'i': 7509, 'w': 'telling'},
#    {'i': 7552, 'w': 'told'},
#    {'i': 7568, 'w': 'saved'},
#    {'i': 8037, 'w': 'Excuse'},
#    {'i': 9011, 'w': 'loves'},
#    {'i': 9397, 'w': 'Excuse'},
#    {'i': 9926, 'w': 'know'},
#    {'i': 11274, 'w': 'called'},
#    {'i': 11289, 'w': 'called'},
#    {'i': 11766, 'w': 'helped'},
#    {'i': 11792, 'w': 'helped'},
#    {'i': 12372, 'w': 'get'},
#    {'i': 12695, 'w': 'Help'},
#    {'i': 12727, 'w': 'give'},
#    {'i': 14566, 'w': 'push'},
#    {'i': 14576, 'w': 'done'},
#    {'i': 16285, 'w': 'help'},
#    {'i': 17473, 'w': 'concerned'},
#    {'i': 17779, 'w': 'Flick'},
#    {'i': 18171, 'w': 'Trust'},
#    {'i': 18403, 'w': 'call'},
#    {'i': 18545, 'w': 'promise'},
#    {'i': 18754, 'w': 'Meet'},
#    {'i': 18987, 'w': 'Tell'},
#    {'i': 19008, 'w': 'shitting'},
#    {'i': 19483, 'w': 'tell'},
#    {'i': 20363, 'w': 'hit'},
#    {'i': 20432, 'w': 'raised'},
#    {'i': 20655, 'w': 'supposed'},
#    {'i': 21412, 'w': 'killed'},
#    {'i': 21915, 'w': 'hit'},
#    {'i': 22345, 'w': 'Excuse'},
#    {'i': 22421, 'w': 'trust'},
#    {'i': 22704, 'w': 'Pardon'},
#    {'i': 23073, 'w': 'Excuse'},
#    {'i': 23831, 'w': 'disgust'},
#    {'i': 25336, 'w': 'Excuse'},
#    {'i': 25488, 'w': 'let'},
#    {'i': 25671, 'w': 'made'},
#    {'i': 26271, 'w': 'hear'},
#    {'i': 27156, 'w': 'See'},
#    {'i': 27397, 'w': 'let'},
#    {'i': 27456, 'w': 'Hit'},
#    {'i': 28005, 'w': 'read'},
#    {'i': 28027, 'w': 'hear'},
#    {'i': 29099, 'w': 'Tell'},
#    {'i': 30654, 'w': 'hear'},
#    {'i': 31091, 'w': 'told'},
#    {'i': 31777, 'w': 'supposed'},
#    {'i': 32758, 'w': 'telling'},
#    {'i': 32809, 'w': 'bumming'},
#    {'i': 32836, 'w': 'reminds'},
#    {'i': 32953, 'w': 'tell'}],
#   'poss': [{'i': 1557, 'w': 'God'},
#    {'i': 1562, 'w': 'God'},
#    {'i': 1882, 'w': 'face'},
#    {'i': 2236, 'w': 'point'},
#    {'i': 2950, 'w': 'asking'},
#    {'i': 3144, 'w': 'ship'},
#    {'i': 3741, 'w': 'father'},
#    {'i': 4060, 'w': 'job'},
#    {'i': 4189, 'w': 'life'},
#    {'i': 1179, 'w': 'know'},
#    {'i': 1197, 'w': 'grovel'},
#    {'i': 1206, 'w': 'move'},
#    {'i': 1244, 'w': 'turns'},
#    {'i': 1250, 'w': 'rubs'},
#    {'i': 1260, 'w': 'leans'},
#    {'i': 1472, 'w': 'walk'},
#    {'i': 1489, 'w': 'stand'},
#    {'i': 1509, 'w': 'stop'},
#    {'i': 1544, 'w': 'struggles'},
#    {'i': 1568, 'w': 'embrace'},
#    {'i': 1613, 'w': 'sitting'},
#    {'i': 1681, 'w': 'did'},
#    {'i': 1684, 'w': 'did'},
#    {'i': 1688, 'w': 'said'},
#    {'i': 1691, 'w': 'gon'},
#    {'i': 1726, 'w': 'opened'},
#    {'i': 1730, 'w': 'walked'},
#    {'i': 1774, 'w': 'thinks'},
#    {'i': 1776, 'w': 'failed'},
#    {'i': 1786, 'w': 'know'},
#    {'i': 1857, 'w': 'fought'},
#    {'i': 1976, 'w': 'focus'},
#    {'i': 2018, 'w': 'stands'},
#    {'i': 2052, 'w': 'goes'},
#    {'i': 2209, 'w': 'made'},
#    {'i': 2293, 'w': 'walks'},
#    {'i': 2368, 'w': 'rips'},
#    {'i': 2376, 'w': 'shoves'},
#    {'i': 2394, 'w': 'find'},
#    {'i': 2399, 'w': 'put'},
#    {'i': 2399, 'w': 'put'},
#    {'i': 2404, 'w': 'hide'},
#    {'i': 2408, 'w': 'falls'},
#    {'i': 2443, 'w': 'falls'},
#    {'i': 6663, 'w': 'sitting'},
#    {'i': 6709, 'w': 'seems'},
#    {'i': 6958, 'w': 'notices'},
#    {'i': 6986, 'w': 'sighs'},
#    {'i': 6991, 'w': 'looking'},
#    {'i': 7036, 'w': 'seen'},
#    {'i': 7092, 'w': 'giving'},
#    {'i': 7115, 'w': 'coming'},
#    {'i': 7442, 'w': 'got'},
#    {'i': 7450, 'w': 'got'},
#    {'i': 7509, 'w': 'telling'},
#    {'i': 7585, 'w': 'come'},
#    {'i': 7669, 'w': 'talk'},
#    {'i': 7674, 'w': 'stay'},
#    {'i': 8462, 'w': 'finishes'},
#    {'i': 8488, 'w': 'knows'},
#    {'i': 8492, 'w': 'fighting'},
#    {'i': 8513, 'w': 'working'},
#    {'i': 8639, 'w': 'falls'},
#    {'i': 8679, 'w': 'uttered'},
#    {'i': 8843, 'w': 'wipes'},
#    {'i': 8848, 'w': 'pushes'},
#    {'i': 9088, 'w': 'know'},
#    {'i': 9210, 'w': 'stop'},
#    {'i': 10079, 'w': 'roll'},
#    {'i': 10084, 'w': 'look'},
#    {'i': 10119, 'w': 'doing'},
#    {'i': 10189, 'w': 'did'},
#    {'i': 10357, 'w': 'replies'},
#    {'i': 10366, 'w': 'reaches'},
#    {'i': 10384, 'w': 'makes'},
#    {'i': 14091, 'w': 'pacing'},
#    {'i': 14564, 'w': 'starts'},
#    {'i': 14576, 'w': 'done'},
#    {'i': 14839, 'w': 'lying'},
#    {'i': 15230, 'w': 'gives'},
#    {'i': 17263, 'w': 'scans'},
#    {'i': 17271, 'w': 'sees'},
#    {'i': 17304, 'w': 'Got'},
#    {'i': 17377, 'w': 'get'},
#    {'i': 17510, 'w': 'coming'},
#    {'i': 17636, 'w': 'did'},
#    {'i': 17658, 'w': 'talking'},
#    {'i': 17713, 'w': 'think'},
#    {'i': 17799, 'w': 'scratches'},
#    {'i': 18273, 'w': 'copy'},
#    {'i': 18545, 'w': 'promise'},
#    {'i': 18550, 'w': 'die'},
#    {'i': 18558, 'w': 'giving'},
#    {'i': 18592, 'w': 'got'},
#    {'i': 18628, 'w': 'Get'},
#    {'i': 18664, 'w': 'drops'},
#    {'i': 18684, 'w': 'falls'},
#    {'i': 18743, 'w': 'grabs'},
#    {'i': 18990, 'w': 'found'},
#    {'i': 19005, 'w': 'got'},
#    {'i': 21855, 'w': 'sitting'},
#    {'i': 21901, 'w': 'know'},
#    {'i': 21962, 'w': 'repeating'},
#    {'i': 21966, 'w': 'know'},
#    {'i': 21971, 'w': 'repeating'},
#    {'i': 21979, 'w': 'repeating'},
#    {'i': 21984, 'w': 'repeating'},
#    {'i': 21988, 'w': 'know'},
#    {'i': 22113, 'w': 'going'},
#    {'i': 22208, 'w': 'talking'},
#    {'i': 22618, 'w': 'looking'},
#    {'i': 22878, 'w': 'grabs'},
#    {'i': 23274, 'w': 'seen'},
#    {'i': 23305, 'w': 'describe'},
#    {'i': 23445, 'w': 'let'},
#    {'i': 24900, 'w': 'acting'},
#    {'i': 25032, 'w': 'think'},
#    {'i': 25102, 'w': 'wanna'},
#    {'i': 25234, 'w': 'places'},
#    {'i': 25241, 'w': 'made'},
#    {'i': 25253, 'w': 'manipulates'},
#    {'i': 25258, 'w': 'places'},
#    {'i': 25274, 'w': 'jump'},
#    {'i': 25280, 'w': 'groan'},
#    {'i': 25549, 'w': 'do'},
#    {'i': 25554, 'w': 'think'},
#    {'i': 25613, 'w': 'saw'},
#    {'i': 25938, 'w': 'move'},
#    {'i': 26733, 'w': 'helps'},
#    {'i': 27120, 'w': 'go'},
#    {'i': 27480, 'w': 'shoots'},
#    {'i': 28574, 'w': 'hugs'},
#    {'i': 28583, 'w': 'hugs'},
#    {'i': 29077, 'w': 'joins'},
#    {'i': 30094, 'w': 'moves'},
#    {'i': 30102, 'w': 'sees'},
#    {'i': 30107, 'w': 'runs'},
#    {'i': 30113, 'w': 'sees'},
#    {'i': 30304, 'w': 'looks'},
#    {'i': 30325, 'w': 'foresaw'},
#    {'i': 30359, 'w': 'makes'},
#    {'i': 30410, 'w': 'has'},
#    {'i': 30442, 'w': 'snaps'},
#    {'i': 30566, 'w': 'stumbles'},
#    {'i': 30619, 'w': 'collapsed'},
#    {'i': 30654, 'w': 'hear'},
#    {'i': 30678, 'w': 'did'},
#    {'i': 30684, 'w': 'did'},
#    {'i': 30813, 'w': 'smiles'},
#    {'i': 30835, 'w': 'gets'},
#    {'i': 30853, 'w': 'rest'},
#    {'i': 30895, 'w': 'died'},
#    {'i': 30930, 'w': 'reunites'},
#    {'i': 31199, 'w': 'sitting'},
#    {'i': 31304, 'w': 'gets'},
#    {'i': 31335, 'w': 'leans'},
#    {'i': 31342, 'w': 'looking'},
#    {'i': 32758, 'w': 'telling'}],
#   'count': 519,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.691,
#     'she/her': 0.1,
#     'they/them/their': 0.124,
#     'xe/xem/xyr/xir': 0.037,
#     'ze/zem/zir/hir': 0.047},
#    'max': 0.691,
#    'total': 78.925},
#   'id': 85,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 60, 'n': 'you'},
#     {'c': 31, 'n': 'his'},
#     {'c': 25, 'n': 'You'},
#     {'c': 18, 'n': 'he'},
#     {'c': 15, 'n': 'him'},
#     {'c': 13, 'n': 'He'},
#     {'c': 4, 'n': 'yourself'},
#     {'c': 3, 'n': 'your'},
#     {'c': 1, 'n': 'YOUR'},
#     {'c': 1, 'n': 'YOU'}],
#    'proper': [{'c': 186, 'n': 'TONY STARK'},
#     {'c': 130, 'n': 'Tony'},
#     {'c': 17, 'n': 'Tony Stark'},
#     {'c': 15, 'n': 'Stark'}]},
#   'mod': [{'i': 2248, 'w': 'sick'},
#    {'i': 2283, 'w': 'blood'},
#    {'i': 9261, 'w': 'able'},
#    {'i': 17653, 'w': 'small'},
#    {'i': 18822, 'w': 'fine'},
#    {'i': 25010, 'w': 'being'},
#    {'i': 30694, 'w': 'unresponsive'},
#    {'i': 30741, 'w': 'able'}],
#   'patient': [{'i': 616, 'w': 'puts'},
#    {'i': 859, 'w': 'taps'},
#    {'i': 1278, 'w': 'carries'},
#    {'i': 1286, 'w': 'lies'},
#    {'i': 1342, 'w': 'forced'},
#    {'i': 1477, 'w': 'supported'},
#    {'i': 1568, 'w': 'embrace'},
#    {'i': 1771, 'w': 'pissed'},
#    {'i': 1923, 'w': 'give'},
#    {'i': 2067, 'w': 'stop'},
#    {'i': 2277, 'w': 'need'},
#    {'i': 6660, 'w': 'see'},
#    {'i': 7099, 'w': 'Thank'},
#    {'i': 7328, 'w': 'means'},
#    {'i': 7509, 'w': 'telling'},
#    {'i': 10450, 'w': 'Thank'},
#    {'i': 15394, 'w': 'has'},
#    {'i': 17250, 'w': 'present'},
#    {'i': 17441, 'w': 'asked'},
#    {'i': 18743, 'w': 'grabs'},
#    {'i': 18774, 'w': 'pushes'},
#    {'i': 19059, 'w': 'hurt'},
#    {'i': 21821, 'w': 'cuts'},
#    {'i': 21962, 'w': 'repeating'},
#    {'i': 21971, 'w': 'repeating'},
#    {'i': 21979, 'w': 'repeating'},
#    {'i': 21984, 'w': 'repeating'},
#    {'i': 21988, 'w': 'know'},
#    {'i': 23082, 'w': 'cut'},
#    {'i': 24853, 'w': 'mourning'},
#    {'i': 27515, 'w': 'uses'},
#    {'i': 28433, 'w': 'seen'},
#    {'i': 28444, 'w': 'punches'},
#    {'i': 28453, 'w': 'stomps'},
#    {'i': 28542, 'w': 'started'},
#    {'i': 28583, 'w': 'hugs'},
#    {'i': 30121, 'w': 'smacks'},
#    {'i': 30125, 'w': 'knocking'},
#    {'i': 30316, 'w': 'reminding'},
#    {'i': 30466, 'w': 'devours'},
#    {'i': 30664, 'w': 'won'},
#    {'i': 30700, 'w': 'hugs'},
#    {'i': 30998, 'w': 'hear'}],
#   'poss': [{'i': 770, 'w': 'hand'},
#    {'i': 792, 'w': 'hand'},
#    {'i': 5502, 'w': 'sits'},
#    {'i': 5574, 'w': 'realizes'},
#    {'i': 5611, 'w': 'starts'},
#    {'i': 5707, 'w': 'starts'},
#    {'i': 5725, 'w': 'know'},
#    {'i': 5735, 'w': 'seem'},
#    {'i': 5765, 'w': 'wipes'},
#    {'i': 5807, 'w': 'know'},
#    {'i': 5844, 'w': 'know'},
#    {'i': 5885, 'w': 'does'},
#    {'i': 5919, 'w': 'know'},
#    {'i': 6367, 'w': 'share'},
#    {'i': 6367, 'w': 'share'},
#    {'i': 6979, 'w': 'get'},
#    {'i': 7686, 'w': 'walking'},
#    {'i': 9881, 'w': 'pulls'},
#    {'i': 9888, 'w': 'shuts'},
#    {'i': 9966, 'w': 'says'},
#    {'i': 9971, 'w': 'shakes'},
#    {'i': 9975, 'w': 'walks'},
#    {'i': 9999, 'w': 'sitting'},
#    {'i': 10015, 'w': 'looks'},
#    {'i': 10029, 'w': 'looks'},
#    {'i': 10035, 'w': 'breaks'},
#    {'i': 10044, 'w': 'looks'},
#    {'i': 10102, 'w': 'turned'},
#    {'i': 10124, 'w': 'gets'},
#    {'i': 10131, 'w': 'walks'},
#    {'i': 10203, 'w': 'did'},
#    {'i': 10227, 'w': 'holds'},
#    {'i': 10336, 'w': 'Sounds'},
#    {'i': 10344, 'w': 'reaches'},
#    {'i': 10407, 'w': 'made'},
#    {'i': 10439, 'w': 'fits'},
#    {'i': 10450, 'w': 'Thank'},
#    {'i': 14260, 'w': 'Let'},
#    {'i': 14797, 'w': 'looks'},
#    {'i': 14804, 'w': 'falls'},
#    {'i': 14839, 'w': 'lying'},
#    {'i': 15508, 'w': 'Feel'},
#    {'i': 16578, 'w': 'look'},
#    {'i': 17339, 'w': 'Got'},
#    {'i': 17463, 'w': 'look'},
#    {'i': 18030, 'w': 'walks'},
#    {'i': 18033, 'w': 'hits'},
#    {'i': 18177, 'w': 'leans'},
#    {'i': 18195, 'w': 'walks'},
#    {'i': 18970, 'w': 'having'},
#    {'i': 18996, 'w': 'looks'},
#    {'i': 19019, 'w': 'sees'},
#    {'i': 19066, 'w': 'engages'},
#    {'i': 19073, 'w': 'begin'},
#    {'i': 19228, 'w': 'takes'},
#    {'i': 19237, 'w': 'grab'},
#    {'i': 21848, 'w': 'turns'},
#    {'i': 22532, 'w': 'hide'},
#    {'i': 22676, 'w': 'seen'},
#    {'i': 22813, 'w': 'look'},
#    {'i': 22931, 'w': 'called'},
#    {'i': 23056, 'w': 'get'},
#    {'i': 27538, 'w': 'tries'},
#    {'i': 27545, 'w': 'shielded'},
#    {'i': 27668, 'w': 'picks'},
#    {'i': 27711, 'w': 'proceeds'},
#    {'i': 27733, 'w': 'throws'},
#    {'i': 27745, 'w': 'throws'},
#    {'i': 27768, 'w': 'goes'},
#    {'i': 27793, 'w': 'lines'},
#    {'i': 27799, 'w': 'underarms'},
#    {'i': 27864, 'w': 'tries'},
#    {'i': 27958, 'w': 'gets'},
#    {'i': 27970, 'w': 'tightens'},
#    {'i': 27978, 'w': 'stands'},
#    {'i': 28005, 'w': 'read'},
#    {'i': 28011, 'w': 'stops'},
#    {'i': 28013, 'w': 'looks'},
#    {'i': 28027, 'w': 'hear'},
#    {'i': 28051, 'w': 'looks'},
#    {'i': 28087, 'w': 'share'},
#    {'i': 28309, 'w': 'summons'},
#    {'i': 28395, 'w': 'takes'},
#    {'i': 28848, 'w': 'want'},
#    {'i': 28860, 'w': 'Get'},
#    {'i': 28983, 'w': 'gon'},
#    {'i': 29640, 'w': 'throws'},
#    {'i': 29645, 'w': 'shoots'}],
#   'count': 354,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.787,
#     'she/her': 0.047,
#     'they/them/their': 0.152,
#     'xe/xem/xyr/xir': 0.007,
#     'ze/zem/zir/hir': 0.007},
#    'max': 0.787,
#    'total': 48.392},
#   'id': 79,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 28, 'n': 'his'},
#     {'c': 26, 'n': 'you'},
#     {'c': 15, 'n': 'him'},
#     {'c': 14, 'n': 'He'},
#     {'c': 12, 'n': 'You'},
#     {'c': 7, 'n': 'your'},
#     {'c': 5, 'n': 'he'},
#     {'c': 1, 'n': 'I.'},
#     {'c': 1, 'n': 'himself'},
#     {'c': 1, 'n': 'ya'}],
#    'proper': [{'c': 208, 'n': 'STEVE ROGERS'},
#     {'c': 26, 'n': 'Nat'},
#     {'c': 3, 'n': 'STEVE'},
#     {'c': 2, 'n': 'STEVE ROGERS Nat'},
#     {'c': 2, 'n': 'Future STEVE ROGERS'},
#     {'c': 1, 'n': 'Nathaniel'},
#     {'c': 1, 'n': 'STEVE ROGERS Things'},
#     {'c': 1, 'n': 'STEVE ROGERSgoes'}]},
#   'mod': [{'i': 2428, 'w': 'ROGERS'},
#    {'i': 5849, 'w': 'about'},
#    {'i': 7702, 'w': 'scared'},
#    {'i': 7710, 'w': 'wrong'},
#    {'i': 17479, 'w': 'ass'},
#    {'i': 22055, 'w': 'options'},
#    {'i': 22364, 'w': 'sure'},
#    {'i': 22594, 'w': 'new'}],
#   'patient': [{'i': 347, 'w': 'facing'},
#    {'i': 1423, 'w': 'see'},
#    {'i': 1500, 'w': 'joins'},
#    {'i': 1509, 'w': 'stop'},
#    {'i': 2159, 'w': 'lost'},
#    {'i': 2394, 'w': 'find'},
#    {'i': 2628, 'w': 'tell'},
#    {'i': 5867, 'w': 'hit'},
#    {'i': 5885, 'w': 'does'},
#    {'i': 5899, 'w': 'Throws'},
#    {'i': 6035, 'w': 'Smiling'},
#    {'i': 7573, 'w': 'face'},
#    {'i': 7729, 'w': 'need'},
#    {'i': 9342, 'w': 'opens'},
#    {'i': 9529, 'w': 'confusing'},
#    {'i': 13263, 'w': 'see'},
#    {'i': 13263, 'w': 'see'},
#    {'i': 15352, 'w': 'See'},
#    {'i': 15394, 'w': 'has'},
#    {'i': 17377, 'w': 'get'},
#    {'i': 18024, 'w': 'sees'},
#    {'i': 19019, 'w': 'sees'},
#    {'i': 19241, 'w': 'knock'},
#    {'i': 19237, 'w': 'grab'},
#    {'i': 21829, 'w': 'defeated'},
#    {'i': 22495, 'w': 'born'},
#    {'i': 22712, 'w': 'know'},
#    {'i': 25924, 'w': 'kicks'},
#    {'i': 26733, 'w': 'helps'},
#    {'i': 27694, 'w': 'battle'},
#    {'i': 27853, 'w': 'throws'}],
#   'poss': [{'i': 1388, 'w': 'beard'},
#    {'i': 1497, 'w': 'arm'},
#    {'i': 2300, 'w': 'face'},
#    {'i': 2382, 'w': 'hand'},
#    {'i': 2588, 'w': 'territory'},
#    {'i': 3174, 'w': 'seat'},
#    {'i': 3184, 'w': 'eyes'},
#    {'i': 5799, 'w': 'friend'},
#    {'i': 5901, 'w': 'jacket'},
#    {'i': 6416, 'w': 'sandwich'},
#    {'i': 9973, 'w': 'head'},
#    {'i': 10146, 'w': 'question'},
#    {'i': 10231, 'w': 'hand'},
#    {'i': 10258, 'w': 'fingers'},
#    {'i': 10347, 'w': 'hand'},
#    {'i': 10441, 'w': 'arm'},
#    {'i': 15248, 'w': 'speaking'},
#    {'i': 17381, 'w': 'feet'},
#    {'i': 17428, 'w': 'suit'},
#    {'i': 18974, 'w': 'communicator'},
#    {'i': 19022, 'w': 'self'},
#    {'i': 19235, 'w': 'counterpart'},
#    {'i': 22567, 'w': 'mission'},
#    {'i': 22585, 'w': 'project'},
#    {'i': 22874, 'w': 'briefcase'},
#    {'i': 22995, 'w': 'job'},
#    {'i': 25951, 'w': 'arm'},
#    {'i': 26694, 'w': 'shield'},
#    {'i': 26738, 'w': 'feet'},
#    {'i': 27701, 'w': 'shield'},
#    {'i': 27703, 'w': 'Mjolnir'},
#    {'i': 27735, 'w': 'shield'},
#    {'i': 27737, 'w': 'THANOS'},
#    {'i': 27741, 'w': 'deflects'},
#    {'i': 27752, 'w': 'shield'},
#    {'i': 27764, 'w': 'feet'},
#    {'i': 27777, 'w': 'shield'},
#    {'i': 27795, 'w': 'arm'},
#    {'i': 27836, 'w': 'hand'},
#    {'i': 27845, 'w': 'shield'},
#    {'i': 27962, 'w': 'feet'},
#    {'i': 27973, 'w': 'shield'},
#    {'i': 27976, 'w': 'arm'},
#    {'i': 27994, 'w': 'communicator'},
#    {'i': 28046, 'w': 'left'},
#    {'i': 28060, 'w': 'side'}]},
#  {'agent': [{'i': 2472, 'w': 'gave'},
#    {'i': 3625, 'w': 'murdered'},
#    {'i': 3630, 'w': 'pushes'},
#    {'i': 3648, 'w': 'Punched'},
#    {'i': 3672, 'w': 'used'},
#    {'i': 7798, 'w': 'looks'},
#    {'i': 7936, 'w': 'lost'},
#    {'i': 7940, 'w': 'lost'},
#    {'i': 8106, 'w': 'say'},
#    {'i': 9278, 'w': 'fiddling'},
#    {'i': 9418, 'w': 'say'},
#    {'i': 9438, 'w': 'kidding'},
#    {'i': 9539, 'w': 'got'},
#    {'i': 9558, 'w': 'presses'},
#    {'i': 9564, 'w': 'disappears'},
#    {'i': 9587, 'w': 'presses'},
#    {'i': 9597, 'w': 'comes'},
#    {'i': 9748, 'w': 'bring'},
#    {'i': 10675, 'w': 'walks'},
#    {'i': 10689, 'w': 'hands'},
#    {'i': 10777, 'w': 'get'},
#    {'i': 10784, 'w': 'look'},
#    {'i': 10851, 'w': 'spots'},
#    {'i': 10871, 'w': 'come'},
#    {'i': 10924, 'w': "doin'"},
#    {'i': 11003, 'w': 'walking'},
#    {'i': 11115, 'w': 'notices'},
#    {'i': 11119, 'w': 'standing'},
#    {'i': 11123, 'w': 'cracks'},
#    {'i': 11181, 'w': 'know'},
#    {'i': 11469, 'w': 'walks'},
#    {'i': 11473, 'w': 'places'},
#    {'i': 11641, 'w': 'brushes'},
#    {'i': 11817, 'w': 'ask'},
#    {'i': 11874, 'w': 'think'},
#    {'i': 11951, 'w': 'offering'},
#    {'i': 13342, 'w': 'gon'},
#    {'i': 13388, 'w': 'know'},
#    {'i': 13405, 'w': 'know'},
#    {'i': 13657, 'w': 'travel'},
#    {'i': 14849, 'w': 'lying'},
#    {'i': 15484, 'w': 'passes'},
#    {'i': 15495, 'w': 'puts'},
#    {'i': 15533, 'w': 'pretends'},
#    {'i': 15543, 'w': 'tears'},
#    {'i': 15549, 'w': 'walks'},
#    {'i': 15557, 'w': 'punches'},
#    {'i': 15574, 'w': 'picks'},
#    {'i': 15579, 'w': 'throws'},
#    {'i': 15612, 'w': 'tries'},
#    {'i': 15693, 'w': 'points'},
#    {'i': 15766, 'w': 'makes'},
#    {'i': 15815, 'w': 'looks'},
#    {'i': 17825, 'w': 'makes'},
#    {'i': 17830, 'w': 'finds'},
#    {'i': 17864, 'w': 'think'},
#    {'i': 17889, 'w': 'draws'},
#    {'i': 17900, 'w': 'Stop'},
#    {'i': 17906, 'w': 'follows'},
#    {'i': 18218, 'w': 'looks'},
#    {'i': 18774, 'w': 'pushes'},
#    {'i': 19282, 'w': 'lying'},
#    {'i': 19293, 'w': 'sleeping'},
#    {'i': 19300, 'w': 'tries'},
#    {'i': 19309, 'w': 'have'},
#    {'i': 19405, 'w': 'experience'},
#    {'i': 19607, 'w': 'leaving'},
#    {'i': 19622, 'w': 'have'},
#    {'i': 19692, 'w': 'say'},
#    {'i': 24820, 'w': 'falls'},
#    {'i': 24825, 'w': 'pounds'},
#    {'i': 24853, 'w': 'mourning'},
#    {'i': 25169, 'w': 'grabs'},
#    {'i': 25185, 'w': 'turns'},
#    {'i': 25274, 'w': 'jump'},
#    {'i': 25280, 'w': 'groan'},
#    {'i': 25657, 'w': 'takes'},
#    {'i': 25710, 'w': 'remember'},
#    {'i': 25790, 'w': 'puts'},
#    {'i': 25807, 'w': 'overwhelms'},
#    {'i': 25811, 'w': 'grunts'},
#    {'i': 25889, 'w': 'screams'},
#    {'i': 25913, 'w': 'faints'},
#    {'i': 25917, 'w': 'slides'},
#    {'i': 32549, 'w': 'looks'}],
#   'count': 283,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.811,
#     'she/her': 0.113,
#     'they/them/their': 0.077,
#     'xe/xem/xyr/xir': 0.0,
#     'ze/zem/zir/hir': 0.0},
#    'max': 0.811,
#    'total': 200040.922},
#   'id': 119,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 32, 'n': 'you'},
#     {'c': 17, 'n': 'his'},
#     {'c': 13, 'n': 'He'},
#     {'c': 10, 'n': 'him'},
#     {'c': 9, 'n': 'You'},
#     {'c': 6, 'n': 'your'},
#     {'c': 4, 'n': 'he'},
#     {'c': 1, 'n': 'me'},
#     {'c': 1, 'n': 'My'},
#     {'c': 1, 'n': 'His'}],
#    'proper': [{'c': 182, 'n': 'BRUCE'},
#     {'c': 2, 'n': 'BRUCE Buster'},
#     {'c': 2, 'n': 'Mr. BRUCE'},
#     {'c': 1, 'n': 'the BRUCE'},
#     {'c': 1, 'n': 'The BRUCE'},
#     {'c': 1, 'n': 'Professor BRUCE'}]},
#   'mod': [{'i': 3645, 'w': 'grateful'},
#    {'i': 7976, 'w': 'kind'},
#    {'i': 9547, 'w': 'right'},
#    {'i': 19808, 'w': 'right'},
#    {'i': 25837, 'w': 'okay'},
#    {'i': 25837, 'w': 'okay'}],
#   'patient': [{'i': 3630, 'w': 'pushes'},
#    {'i': 7785, 'w': 'see'},
#    {'i': 7953, 'w': 'blamed'},
#    {'i': 7969, 'w': 'treating'},
#    {'i': 8335, 'w': 'Thank'},
#    {'i': 9971, 'w': 'shakes'},
#    {'i': 10900, 'w': 'liked'},
#    {'i': 10935, 'w': 'see'},
#    {'i': 11988, 'w': 'ignores'},
#    {'i': 13058, 'w': 'see'},
#    {'i': 17979, 'w': 'see'},
#    {'i': 19334, 'w': 'help'},
#    {'i': 19819, 'w': 'Thank'},
#    {'i': 25807, 'w': 'overwhelms'},
#    {'i': 25938, 'w': 'move'}],
#   'poss': [{'i': 8386, 'w': 'Mom'},
#    {'i': 9954, 'w': 'hands'},
#    {'i': 9954, 'w': 'hands'},
#    {'i': 10720, 'w': 'Ship'},
#    {'i': 10893, 'w': 'change'},
#    {'i': 11586, 'w': 'shoulder'},
#    {'i': 11588, 'w': 'points'},
#    {'i': 13666, 'w': 'future'},
#    {'i': 13671, 'w': 'present'},
#    {'i': 13685, 'w': 'future'},
#    {'i': 15492, 'w': 'way'},
#    {'i': 15497, 'w': 'hand'},
#    {'i': 15500, 'w': 'face'},
#    {'i': 15545, 'w': 'shirt'},
#    {'i': 15801, 'w': 'form'},
#    {'i': 15805, 'w': 'body'},
#    {'i': 15866, 'w': 'cell'},
#    {'i': 17891, 'w': 'fist'},
#    {'i': 18802, 'w': 'rampage'},
#    {'i': 19349, 'w': 'Reality'},
#    {'i': 19444, 'w': 'reality'},
#    {'i': 19561, 'w': 'form'},
#    {'i': 19589, 'w': 'point'},
#    {'i': 19762, 'w': 'body'},
#    {'i': 24823, 'w': 'knees'},
#    {'i': 25181, 'w': 'anger'},
#    {'i': 25195, 'w': 'face'},
#    {'i': 25801, 'w': 'hand'},
#    {'i': 25899, 'w': 'body'},
#    {'i': 25910, 'w': 'fingers'},
#    {'i': 25920, 'w': 'arm'}]},
#  {'agent': [{'i': 3000, 'w': 'stands'},
#    {'i': 3003, 'w': 'walks'},
#    {'i': 3015, 'w': 'holds'},
#    {'i': 3021, 'w': 'catches'},
#    {'i': 3511, 'w': 'flies'},
#    {'i': 3514, 'w': 'slices'},
#    {'i': 3791, 'w': 'raises'},
#    {'i': 3835, 'w': 'do'},
#    {'i': 3839, 'w': 'looks'},
#    {'i': 3846, 'w': 'done'},
#    {'i': 3860, 'w': 'walks'},
#    {'i': 11068, 'w': 'put'},
#    {'i': 11105, 'w': 'grabs'},
#    {'i': 11296, 'w': 'walks'},
#    {'i': 11301, 'w': 'takes'},
#    {'i': 11396, 'w': 'brings'},
#    {'i': 11456, 'w': 'uses'},
#    {'i': 11579, 'w': 'puts'},
#    {'i': 11721, 'w': 'walks'},
#    {'i': 11764, 'w': 'know'},
#    {'i': 11792, 'w': 'helped'},
#    {'i': 11984, 'w': 'shakes'},
#    {'i': 11988, 'w': 'ignores'},
#    {'i': 14272, 'w': 'know'},
#    {'i': 14278, 'w': 'sitting'},
#    {'i': 14321, 'w': 'wakes'},
#    {'i': 14524, 'w': 'starts'},
#    {'i': 14530, 'w': 'seems'},
#    {'i': 15918, 'w': 'gon'},
#    {'i': 15925, 'w': 'gon'},
#    {'i': 16025, 'w': 'try'},
#    {'i': 16042, 'w': 'sees'},
#    {'i': 16171, 'w': 'think'},
#    {'i': 16184, 'w': 'think'},
#    {'i': 16219, 'w': 'miss'},
#    {'i': 16246, 'w': 'help'},
#    {'i': 16258, 'w': 'brush'},
#    {'i': 16300, 'w': 'crying'},
#    {'i': 16316, 'w': 'do'},
#    {'i': 16321, 'w': 'do'},
#    {'i': 16358, 'w': 'runs'},
#    {'i': 17876, 'w': 'Take'},
#    {'i': 18851, 'w': 'uses'},
#    {'i': 20200, 'w': 'tries'},
#    {'i': 20211, 'w': 'gets'},
#    {'i': 20215, 'w': 'sees'},
#    {'i': 20232, 'w': 'doing'},
#    {'i': 20299, 'w': 'wearing'},
#    {'i': 20452, 'w': 'attempts'},
#    {'i': 20910, 'w': 'holds'},
#    {'i': 20942, 'w': 'summons'},
#    {'i': 25493, 'w': 'tears'},
#    {'i': 25596, 'w': 'lets'},
#    {'i': 25860, 'w': 'gives'},
#    {'i': 26767, 'w': 'doing'},
#    {'i': 26797, 'w': 'have'},
#    {'i': 27074, 'w': 'lights'},
#    {'i': 27120, 'w': 'go'},
#    {'i': 27461, 'w': 'bangs'},
#    {'i': 27502, 'w': 'grabs'},
#    {'i': 27505, 'w': 'uses'},
#    {'i': 27573, 'w': 'punches'},
#    {'i': 27606, 'w': 'tries'},
#    {'i': 27612, 'w': 'grabs'},
#    {'i': 27621, 'w': 'tries'},
#    {'i': 28316, 'w': 'makes'},
#    {'i': 30131, 'w': 'arrives'},
#    {'i': 31756, 'w': 'nods'},
#    {'i': 31822, 'w': 'offers'},
#    {'i': 31833, 'w': 'do'},
#    {'i': 31899, 'w': 'walks'},
#    {'i': 31923, 'w': 'removes'},
#    {'i': 31949, 'w': 'touches'},
#    {'i': 31966, 'w': 'know'},
#    {'i': 32002, 'w': 'say'},
#    {'i': 32009, 'w': 'touch'},
#    {'i': 32016, 'w': 'think'},
#    {'i': 32022, 'w': 'realize'},
#    {'i': 32080, 'w': 'fight'},
#    {'i': 32243, 'w': 'have'},
#    {'i': 32253, 'w': 'got'},
#    {'i': 32259, 'w': 'gon'},
#    {'i': 32287, 'w': 'know'},
#    {'i': 32332, 'w': 'know'},
#    {'i': 32336, 'w': 'want'},
#    {'i': 32393, 'w': 'taking'}],
#   'count': 282,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.544,
#     'she/her': 0.217,
#     'they/them/their': 0.079,
#     'xe/xem/xyr/xir': 0.068,
#     'ze/zem/zir/hir': 0.091},
#    'max': 0.544,
#    'total': 49.639},
#   'id': 96,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 35, 'n': 'you'},
#     {'c': 19, 'n': 'his'},
#     {'c': 14, 'n': 'You'},
#     {'c': 12, 'n': 'him'},
#     {'c': 11, 'n': 'he'},
#     {'c': 5, 'n': 'your'},
#     {'c': 3, 'n': 'He'},
#     {'c': 3, 'n': 'His'},
#     {'c': 3, 'n': 'Your'},
#     {'c': 2, 'n': 'himself'}],
#    'proper': [{'c': 93, 'n': 'THOR'}, {'c': 82, 'n': 'Thor'}]},
#   'mod': [{'i': 14295, 'w': 'awake'},
#    {'i': 14297, 'w': 'asleep'},
#    {'i': 14305, 'w': 'asleep'},
#    {'i': 14317, 'w': 'dead'},
#    {'i': 16012, 'w': 'drunk'}],
#   'patient': [{'i': 3800, 'w': 'stop'},
#    {'i': 11296, 'w': 'walks'},
#    {'i': 11401, 'w': 'Thank'},
#    {'i': 11396, 'w': 'brings'},
#    {'i': 11421, 'w': 'Thank'},
#    {'i': 11469, 'w': 'walks'},
#    {'i': 11655, 'w': 'scare'},
#    {'i': 11721, 'w': 'walks'},
#    {'i': 11977, 'w': 'need'},
#    {'i': 12961, 'w': 'see'},
#    {'i': 14321, 'w': 'wakes'},
#    {'i': 16161, 'w': 'slaps'},
#    {'i': 17713, 'w': 'think'},
#    {'i': 18851, 'w': 'uses'},
#    {'i': 20286, 'w': 'Trying'},
#    {'i': 24890, 'w': 'asked'},
#    {'i': 25336, 'w': 'Excuse'},
#    {'i': 25348, 'w': 'holding'},
#    {'i': 25537, 'w': 'telling'},
#    {'i': 25582, 'w': 'help'},
#    {'i': 26744, 'w': 'join'},
#    {'i': 26886, 'w': 'kill'},
#    {'i': 27074, 'w': 'lights'},
#    {'i': 27565, 'w': 'beaten'},
#    {'i': 27583, 'w': 'beats'},
#    {'i': 27587, 'w': 'throwing'},
#    {'i': 27593, 'w': 'socking'},
#    {'i': 27596, 'w': 'throwing'},
#    {'i': 27601, 'w': 'socking'},
#    {'i': 27623, 'w': 'defend'},
#    {'i': 27630, 'w': 'starts'},
#    {'i': 27686, 'w': 'kicks'},
#    {'i': 28395, 'w': 'takes'},
#    {'i': 28395, 'w': 'takes'},
#    {'i': 31756, 'w': 'nods'},
#    {'i': 32411, 'w': 'miss'}],
#   'poss': [{'i': 3017, 'w': 'hand'},
#    {'i': 3785, 'w': 'face'},
#    {'i': 3871, 'w': 'steps'},
#    {'i': 11303, 'w': 'headphones'},
#    {'i': 11398, 'w': 'headphones'},
#    {'i': 11478, 'w': 'shoulder'},
#    {'i': 11533, 'w': 'help'},
#    {'i': 11574, 'w': 'smile'},
#    {'i': 11635, 'w': 'hand'},
#    {'i': 11645, 'w': 'hand'},
#    {'i': 11811, 'w': 'beer'},
#    {'i': 11986, 'w': 'head'},
#    {'i': 14284, 'w': 'sunglasses'},
#    {'i': 16044, 'w': 'mother'},
#    {'i': 16221, 'w': 'Mom'},
#    {'i': 16263, 'w': 'beard'},
#    {'i': 10621, 'w': 'getting'},
#    {'i': 10645, 'w': 'drops'},
#    {'i': 10684, 'w': 'dropped'},
#    {'i': 10700, 'w': 'takes'},
#    {'i': 13198, 'w': 'calm'},
#    {'i': 13233, 'w': 'presses'},
#    {'i': 13242, 'w': 'grows'},
#    {'i': 13618, 'w': 'Die'},
#    {'i': 14819, 'w': 'makes'},
#    {'i': 18498, 'w': 'inhales'},
#    {'i': 18648, 'w': 'goes'},
#    {'i': 18652, 'w': 'pulls'},
#    {'i': 18664, 'w': 'drops'},
#    {'i': 18732, 'w': 'pushes'},
#    {'i': 21855, 'w': 'sitting'},
#    {'i': 21927, 'w': 'said'},
#    {'i': 22010, 'w': 'went'},
#    {'i': 22004, 'w': 'wanted'},
#    {'i': 22010, 'w': 'went'},
#    {'i': 22029, 'w': 'ruined'},
#    {'i': 25336, 'w': 'Excuse'},
#    {'i': 25973, 'w': 'walks'},
#    {'i': 25979, 'w': 'sees'},
#    {'i': 28903, 'w': 'Hold'},
#    {'i': 28908, 'w': 'shrinks'},
#    {'i': 28913, 'w': 'pulls'},
#    {'i': 28929, 'w': 'presses'},
#    {'i': 28999, 'w': 'need'},
#    {'i': 29043, 'w': 'share'},
#    {'i': 29087, 'w': 'said'},
#    {'i': 30967, 'w': 'watches'}],
#   'count': 260,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.56,
#     'she/her': 0.149,
#     'they/them/their': 0.259,
#     'xe/xem/xyr/xir': 0.016,
#     'ze/zem/zir/hir': 0.016},
#    'max': 0.56,
#    'total': 38.138},
#   'id': 108,
# ...
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 826,
#   'mentions': {'common': [{'c': 1, 'n': 'Medic'}, {'c': 1, 'n': 'MEDIC'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 18948, 'w': 'blew'}],
#   'count': 2,
#   'g': None,
#   'id': 832,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'us'}, {'c': 1, 'n': 'we'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 1.0,
#     'she/her': 0,
#     'they/them/their': 0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 836,
#   'mentions': {'common': [{'c': 1, 'n': 'his counterpart'}],
#    'pronoun': [{'c': 1, 'n': 'him'}],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 19233, 'w': 'punch'}],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.2,
#     'she/her': 0.2,
#     'they/them/their': 0.2,
#     'xe/xem/xyr/xir': 0.2,
#     'ze/zem/zir/hir': 0.2},
#    'max': 0.2,
#    'total': 0.5},
#   'id': 179,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'your'}],
#    'proper': [{'c': 1, 'n': 'Doctor'}]},
#   'mod': [],
#   'patient': [],
#   'poss': [{'i': 19490, 'w': 'science'}]},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'she/her',
#    'inference': {'he/him/his': 0.092,
#     'she/her': 0.713,
#     'they/them/their': 0.065,
#     'xe/xem/xyr/xir': 0.065,
#     'ze/zem/zir/hir': 0.065},
#    'max': 0.713,
#    'total': 1.542},
#   'id': 182,
#   'mentions': {'common': [], 'pronoun': [], 'proper': [{'c': 2, 'n': 'Sire'}]},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 856,
#   'mentions': {'common': [{'c': 1, 'n': 'Avengers'},
#     {'c': 1, 'n': 'AVENGERS'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 857,
#   'mentions': {'common': [{'c': 1, 'n': 'My ladies'}],
#    'pronoun': [{'c': 1, 'n': 'you'}],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 20191, 'w': 'see'}],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 1.0,
#     'she/her': 0,
#     'they/them/their': 0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 859,
#   'mentions': {'common': [{'c': 1, 'n': 'your brother'}],
#    'pronoun': [{'c': 1, 'n': 'his'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': [{'i': 20290, 'w': 'belly'}]},
#  {'agent': [{'i': 20504, 'w': 'talk'}, {'i': 20509, 'w': 'hug'}],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 863,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'We'}, {'c': 1, 'n': 'They'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 868,
#   'mentions': {'common': [{'c': 2, 'n': 'everyone else'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 873,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'you'}], 'proper': []},
#   'mod': [],
#   'patient': [{'i': 20706, 'w': 'missed'}],
#   'poss': []},
#  {'agent': [{'i': 22441, 'w': 'go'}],
#   'count': 2,
#   'g': None,
#   'id': 927,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'we'}, {'c': 1, 'n': 'OUR'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.355,
#     'she/her': 0.161,
#     'they/them/their': 0.161,
#     'xe/xem/xyr/xir': 0.161,
#     'ze/zem/zir/hir': 0.161},
#    'max': 0.355,
#    'total': 0.62},
#   'id': 189,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'him'}],
#    'proper': [{'c': 1, 'n': 'Dr. Zola'}]},
#   'mod': [],
#   'patient': [{'i': 22676, 'w': 'seen'}],
#   'poss': []},
#  {'agent': [{'i': 23212, 'w': 'turn'}],
#   'count': 2,
#   'g': {'argmax': 'she/her',
#    'inference': {'he/him/his': 0,
#     'she/her': 1.0,
#     'they/them/their': 0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 957,
#   'mentions': {'common': [{'c': 1, 'n': 'A girl'}],
#    'pronoun': [{'c': 1, 'n': 'she'}],
#    'proper': []},
#   'mod': [{'i': 23204, 'w': 'nice'}],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0.124,
#     'she/her': 0.124,
#     'they/them/their': 0.503,
#     'xe/xem/xyr/xir': 0.124,
#     'ze/zem/zir/hir': 0.124},
#    'max': 0.503,
#    'total': 0.805},
#   'id': 193,
#   'mentions': {'common': [],
#    'pronoun': [],
#    'proper': [{'c': 2, 'n': 'ELEVATOR LADY'}]},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 976,
#   'mentions': {'common': [{'c': 1, 'n': 'my Dad'}, {'c': 1, 'n': 'my dad'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [{'i': 23550, 'w': 'tough'}],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 1.0,
#     'she/her': 0,
#     'they/them/their': 0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 981,
#   'mentions': {'common': [{'c': 1, 'n': 'That kid'}],
#    'pronoun': [{'c': 1, 'n': 'him'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.728,
#     'she/her': 0.149,
#     'they/them/their': 0.085,
#     'xe/xem/xyr/xir': 0.019,
#     'ze/zem/zir/hir': 0.019},
#    'max': 0.728,
#    'total': 10.68},
#   'id': 199,
#   'mentions': {'common': [],
#    'pronoun': [],
#    'proper': [{'c': 1, 'n': 'EDWIN JARVIS'}, {'c': 1, 'n': 'Ned'}]},
#   'mod': [],
#   'patient': [{'i': 23682, 'w': 'met'}],
#   'poss': []},
#  {'agent': [{'i': 24193, 'w': 'making'}, {'i': 24216, 'w': 'knows'}],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 1.0,
#     'she/her': 0,
#     'they/them/their': 0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 2},
#   'id': 999,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'he'}], 'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 24720, 'w': 'joined'}],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 1016,
#   'mentions': {'common': [{'c': 1,
#      'n': 'the others returning from their journeys'}],
#    'pronoun': [{'c': 1, 'n': 'their'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': [{'i': 24727, 'w': 'journeys'}]},
#  {'agent': [{'i': 30597, 'w': 'fading'}],
#   'count': 2,
#   'g': None,
#   'id': 1027,
#   'mentions': {'common': [{'c': 2, 'n': 'friend'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 24853, 'w': 'mourning'}],
#   'poss': []},
#  {'agent': [{'i': 29533, 'w': 'do'}],
#   'count': 2,
#   'g': None,
#   'id': 1033,
#   'mentions': {'common': [{'c': 1, 'n': 'the others'},
#     {'c': 1, 'n': 'The others'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 25638, 'w': 'know'}, {'i': 25645, 'w': 'do'}],
#   'count': 2,
#   'g': None,
#   'id': 1046,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'we'}, {'c': 1, 'n': 'We'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 1047,
#   'mentions': {'common': [{'c': 1, 'n': 'everyone THANOS'}],
#    'pronoun': [{'c': 1, 'n': 'them'}],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 25710, 'w': 'remember'}, {'i': 25720, 'w': 'bringing'}],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 1049,
#   'mentions': {'common': [{'c': 1, 'n': 'boss'}, {'c': 1, 'n': 'Boss'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 27515, 'w': 'uses'}],
#   'poss': []},
#  {'agent': [{'i': 26248, 'w': 'drowning'}],
#   'count': 2,
#   'g': None,
#   'id': 1061,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'We'}], 'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 1064,
#   'mentions': {'common': [{'c': 2, 'n': 'Outriders'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 26690, 'w': 'has'}],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 1.0,
#     'she/her': 0,
#     'they/them/their': 0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 1077,
#   'mentions': {'common': [{'c': 1, 'n': 'my man'}],
#    'pronoun': [{'c': 1, 'n': 'He'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 26980, 'w': 'resist'}],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 1082,
#   'mentions': {'common': [{'c': 1,
#      'n': 'those that are unable to accept what can be'}],
#    'pronoun': [{'c': 1, 'n': 'They'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 27372, 'w': 'become'}],
#   'count': 2,
#   'g': None,
#   'id': 1090,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'us'}, {'c': 1, 'n': 'we'}],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 27309, 'w': 'betraying'}],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 1096,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'you'}, {'c': 1, 'n': 'your'}],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 27890, 'w': 'tell'}],
#   'poss': [{'i': 27901, 'w': 'stubborn'}]},
#  {'agent': [{'i': 28106, 'w': 'see'}, {'i': 28123, 'w': 'see'}],
#   'count': 2,
#   'g': None,
#   'id': 1104,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'we'}], 'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 28154, 'w': 'arrive'}],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 1107,
#   'mentions': {'common': [{'c': 1, 'n': 'more and more heroes'}],
#    'pronoun': [{'c': 1, 'n': 'their'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': [{'i': 28169, 'w': 'own'}]},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 1133,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'we'}, {'c': 1, 'n': 'us'}],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 28535, 'w': 'need'}],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 1134,
#   'mentions': {'common': [{'c': 1, 'n': 'a bunch of Sakaarans'}],
#    'pronoun': [{'c': 1, 'n': 'them'}],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 28602, 'w': 'Fighting'}],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 1140,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'It'}], 'proper': []},
#   'mod': [{'i': 29165, 'w': 'mess'}],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 29705, 'w': 'turn'}, {'i': 29738, 'w': 'firing'}],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 2},
#   'id': 1155,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'they'}], 'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 2},
#   'id': 1167,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'them'}], 'proper': []},
#   'mod': [],
#   'patient': [{'i': 30160, 'w': 'knocks'}],
#   'poss': []},
#  {'agent': [{'i': 30846, 'w': 'gon'}, {'i': 30912, 'w': 'cut'}],
#   'count': 2,
#   'g': None,
#   'id': 1174,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'We'}], 'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': None,
#   'id': 1178,
#   'mentions': {'common': [{'c': 2, 'n': 'his family'}],
#    'pronoun': [],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 30950, 'w': 'share'}],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 2},
#   'id': 1181,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'They'}, {'c': 1, 'n': 'their'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': [{'i': 30991, 'w': 'balcony'}]},
#  {'agent': [{'i': 31576, 'w': 'won'}, {'i': 31587, 'w': 'did'}],
#   'count': 2,
#   'g': None,
#   'id': 1198,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'we'}, {'c': 1, 'n': 'We'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 31698, 'w': 'cut'}, {'i': 31715, 'w': 'expect'}],
#   'count': 2,
#   'g': None,
#   'id': 1202,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'we'}], 'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 31730, 'w': 'need'}, {'i': 31740, 'w': 'have'}],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 1204,
#   'mentions': {'common': [{'c': 1, 'n': 'Your people'}],
#    'pronoun': [{'c': 1, 'n': 'they'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'they/them/their',
#    'inference': {'he/him/his': 0,
#     'she/her': 0,
#     'they/them/their': 1.0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 1},
#   'id': 1209,
#   'mentions': {'common': [{'c': 1, 'n': 'The Asgardians of the Galaxy'}],
#    'pronoun': [{'c': 1, 'n': 'their'}],
#    'proper': []},
#   'mod': [],
#   'patient': [{'i': 31923, 'w': 'removes'}],
#   'poss': [{'i': 31956, 'w': 'destination'}]},
#  {'agent': [],
#   'count': 2,
#   'g': {'argmax': 'she/her',
#    'inference': {'he/him/his': 0,
#     'she/her': 1.0,
#     'they/them/their': 0,
#     'xe/xem/xyr/xir': 0,
#     'ze/zem/zir/hir': 0},
#    'max': 1.0,
#    'total': 2},
#   'id': 1214,
#   'mentions': {'common': [], 'pronoun': [{'c': 2, 'n': 'her'}], 'proper': []},
#   'mod': [],
#   'patient': [{'i': 32305, 'w': 'bring'}, {'i': 32316, 'w': 'miss'}],
#   'poss': []},
#  {'agent': [{'i': 32491, 'w': 'meet'}],
#   'count': 2,
#   'g': None,
#   'id': 1223,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'us'}, {'c': 1, 'n': 'We'}],
#    'proper': []},
#   'mod': [],
#   'patient': [],
#   'poss': []},
#  {'agent': [{'i': 33040, 'w': 'performed'}],
#   'count': 2,
#   'g': {'argmax': 'he/him/his',
#    'inference': {'he/him/his': 0.704,
#     'she/her': 0.074,
#     'they/them/their': 0.074,
#     'xe/xem/xyr/xir': 0.074,
#     'ze/zem/zir/hir': 0.074},
#    'max': 0.704,
#    'total': 1.352},
#   'id': 238,
#   'mentions': {'common': [],
#    'pronoun': [{'c': 1, 'n': 'His'}],
#    'proper': [{'c': 1, 'n': 'Harry James'}]},
#   'mod': [],
#   'patient': [],
#   'poss': [{'i': 33046, 'w': 'Orchestra'}]}]

# %%
for character in character_data["characters"]:
    
    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"
    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]
    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

# %%
df_list = []
for character in character_data["characters"]:
    
    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]
        
        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#                 Name  ...                                                                                        Modifiers
# 0         TONY STARK  ...         [(able, 2), (sick, 1), (blood, 1), (small, 1), (fine, 1), (being, 1), (unresponsive, 1)]
# 1       STEVE ROGERS  ...  [(ROGERS, 1), (about, 1), (scared, 1), (wrong, 1), (ass, 1), (options, 1), (sure, 1), (new, 1)]
# 2              BRUCE  ...                                                [(right, 2), (okay, 2), (grateful, 1), (kind, 1)]
# 3               THOR  ...                                                 [(asleep, 2), (awake, 1), (dead, 1), (drunk, 1)]
# 4         SCOTT LANG  ...                                  [(okay, 1), (open, 1), (surprised, 1), (person, 1), (right, 1)]
# 5             THANOS  ...                                                                    [(unbeatable, 1), (death, 1)]
# 6       CLINT BARTON  ...                                                                                     [(alone, 1)]
# 7             Nebula  ...                                                                     [(welcome, 1), (useless, 1)]
# 8   NATASHA ROMANOFF  ...                                                                         [(asleep, 1), (pain, 1)]
# 9             RHODEY  ...                                                                                               []
# 10     CAROL DANVERS  ...                                                                                     [(great, 1)]
# 11            ROCKET  ...                                                                                     [(happy, 1)]
# 12             Peter  ...                                                                                               []
# 13            Gamora  ...                                                                      [(future, 1), (present, 1)]
# 14      MORGAN STARK  ...                                                                                               []
# 15            Pepper  ...                                                                                     [(first, 1)]
# 16      STEVE ROGERS  ...                                                                                               []
# 17      HOWARD STARK  ...                                                                                   [(nervous, 1)]
# 18             Ronin  ...                                                           [(crazy, 1), (about, 1), (fighter, 1)]
# 19               Sam  ...                                                                                      [(fact, 1)]
# 20             Quill  ...                                                                                    [(person, 1)]
# 21              KORG  ...                                                                                               []
# 22           STRANGE  ...                                                                                     [(right, 1)]
# 23            FRIGGA  ...                                                                                    [(better, 1)]
# 24              Lila  ...                                                                                               []
# 25           Akihiko  ...                                                                               [(experienced, 1)]
# 26              Jane  ...                                                                                     [(flame, 1)]
# 27              Loki  ...                                                                                               []
# 28          VALKYRIE  ...                                                                                               []
# 29    WANDA MAXIMOFF  ...                                                                                               []
# 30              BUCK  ...                                                                                               []
# 31            Cassie  ...                                                                                               []
# 32         EBONY MAW  ...                                                                                   [(traitor, 1)]
# 33          T'Challa  ...                                                                                               []
# 34             Okoye  ...                                                                                               []
# 35  ALEXANDER PIERCE  ...                                                                                       [(man, 1)]
# 36           Mjolnir  ...                                                                                               []
# 37       Mungo Jerry  ...                                                                                      [(weak, 1)]
# 38          HANK PYM  ...                                                                                               []
# 39      LAURA BARTON  ...                                                                                               []
# 40           SITWELL  ...                                                                                               []
# 41             BRUCE  ...                                                                                               []
# 42      STEVE ROGERS  ...                                                                                               []
# 43             HAPPY  ...                                                                                               []
# 44    WANDA MAXIMOFF  ...                                                                                               []
# 45              DRAX  ...                                                                                               []
# 46              Hope  ...                                                                                               []
# 47            Father  ...                                                                                               []
# 48        Thumbelina  ...                                                                                               []
# 49            Rhodes  ...                                                                                               []
# 50      Stormbreaker  ...                                                                                               []
# 51         RED SKULL  ...                                                                                               []
# 52             Groot  ...                                                                                               []
# 53  NATASHA ROMANOFF  ...                                                                                               []
# 54             Potts  ...                                                                                               []
# 55             Shuri  ...                                                                                               []
# 56      Peggy Carter  ...                                                                                               []
# 57               Mom  ...                                                                                               []
# 58             Mommy  ...                                                                                               []
# 59             Ronan  ...                                                                                               []
# 60              Wong  ...                                                                                               []
# 61     CORVUS GLAIVE  ...                                                                                               []
# 62      the Avengers  ...                                                                                               []
# 63     COOPER BARTON  ...                                                                                               []
# 64         JOE RUSSO  ...                                                                                               []
# 65               God  ...                                                                                               []
# 66              Miek  ...                                                                                               []
# 67               Dad  ...                                                                                               []
# 68          THE WASP  ...                                                                                               []
# 69              Babe  ...                                                                                               []
# 70               Pep  ...                                                                                               []
# 71              Luis  ...                                                                                               []
# 72             Roger  ...                                                                                               []
# 73             Morag  ...                                                                                               []
# 74            Rumlow  ...                                                                                               []
# 75         Nick Fury  ...                                                                                               []
# 76              Odin  ...                                                                                               []
# 77            Doctor  ...                                                                                               []
# 78              Sire  ...                                                                                               []
# 79          Dr. Zola  ...                                                                                               []
# 80     ELEVATOR LADY  ...                                                                                               []
# 81      EDWIN JARVIS  ...                                                                                               []
# 82       Harry James  ...                                                                                               []
#
# [83 rows x 8 columns]

# %% [markdown]
# # View Character Data

# %% [markdown]
# Let's view the most frequently mentioned characters as well as their referential gender, actions for the which they are the agent and patient, objects they possess, and modifiers.

# %%
df
# Out:
#                 Name  ...                                                                                        Modifiers
# 0         TONY STARK  ...         [(able, 2), (sick, 1), (blood, 1), (small, 1), (fine, 1), (being, 1), (unresponsive, 1)]
# 1       STEVE ROGERS  ...  [(ROGERS, 1), (about, 1), (scared, 1), (wrong, 1), (ass, 1), (options, 1), (sure, 1), (new, 1)]
# 2              BRUCE  ...                                                [(right, 2), (okay, 2), (grateful, 1), (kind, 1)]
# 3               THOR  ...                                                 [(asleep, 2), (awake, 1), (dead, 1), (drunk, 1)]
# 4         SCOTT LANG  ...                                  [(okay, 1), (open, 1), (surprised, 1), (person, 1), (right, 1)]
# 5             THANOS  ...                                                                    [(unbeatable, 1), (death, 1)]
# 6       CLINT BARTON  ...                                                                                     [(alone, 1)]
# 7             Nebula  ...                                                                     [(welcome, 1), (useless, 1)]
# 8   NATASHA ROMANOFF  ...                                                                         [(asleep, 1), (pain, 1)]
# 9             RHODEY  ...                                                                                               []
# 10     CAROL DANVERS  ...                                                                                     [(great, 1)]
# 11            ROCKET  ...                                                                                     [(happy, 1)]
# 12             Peter  ...                                                                                               []
# 13            Gamora  ...                                                                      [(future, 1), (present, 1)]
# 14      MORGAN STARK  ...                                                                                               []
entity_df = pd.read_csv("AvengersFilms_dir/my_film.entities", delimiter='\t')
# Merge character data and entity data on Character ID
entity_df['COREF'] = entity_df['COREF'].astype(str)
entity_df = pd.merge(df[['Character ID', 'Name']], entity_df, left_on = 'Character ID', right_on= 'COREF')
entity_df[:100]
# Out:
#    Character ID        Name COREF  ...  prop  cat        text
# 0            85  TONY STARK    85  ...  PROP  PER        Tony
# 1            85  TONY STARK    85  ...  PROP  PER        Tony
# 2            85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 3            85  TONY STARK    85  ...  PRON  PER         You
# 4            85  TONY STARK    85  ...  PRON  PER         you
# 5            85  TONY STARK    85  ...  PROP  PER        Tony
# 6            85  TONY STARK    85  ...  PROP  PER        Tony
# 7            85  TONY STARK    85  ...  PROP  PER        Tony
# 8            85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 9            85  TONY STARK    85  ...  PROP  PER        Tony
# 10           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 11           85  TONY STARK    85  ...  PRON  PER         you
# 12           85  TONY STARK    85  ...  PROP  PER        Tony
# 13           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 14           85  TONY STARK    85  ...  PRON  PER         you
# 15           85  TONY STARK    85  ...  PROP  PER        Tony
# 16           85  TONY STARK    85  ...  PRON  PER         his
# 17           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 18           85  TONY STARK    85  ...  PROP  PER        Tony
# 19           85  TONY STARK    85  ...  PROP  PER  Tony Stark
# 20           85  TONY STARK    85  ...  PROP  PER  Tony Stark
# 21           85  TONY STARK    85  ...  PRON  PER          he
# 22           85  TONY STARK    85  ...  PROP  PER        Tony
# 23           85  TONY STARK    85  ...  PRON  PER          He
# 24           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 25           85  TONY STARK    85  ...  PROP  PER        Tony
# 26           85  TONY STARK    85  ...  PROP  PER        Tony
# 27           85  TONY STARK    85  ...  PRON  PER          He
# 28           85  TONY STARK    85  ...  PRON  PER         you
# 29           85  TONY STARK    85  ...  PRON  PER         you
# 30           85  TONY STARK    85  ...  PRON  PER         you
# 31           85  TONY STARK    85  ...  PRON  PER         you
# 32           85  TONY STARK    85  ...  PROP  PER        Tony
# 33           85  TONY STARK    85  ...  PRON  PER         his
# 34           85  TONY STARK    85  ...  PRON  PER         You
# 35           85  TONY STARK    85  ...  PRON  PER         You
# 36           85  TONY STARK    85  ...  PROP  PER        Tony
# 37           85  TONY STARK    85  ...  PRON  PER         you
# 38           85  TONY STARK    85  ...  PRON  PER         you
# 39           85  TONY STARK    85  ...  PRON  PER         you
# 40           85  TONY STARK    85  ...  PRON  PER         you
# 41           85  TONY STARK    85  ...  PROP  PER        Tony
# 42           85  TONY STARK    85  ...  PRON  PER          He
# 43           85  TONY STARK    85  ...  PRON  PER         his
# 44           85  TONY STARK    85  ...  PRON  PER         his
# 45           85  TONY STARK    85  ...  PRON  PER         him
# 46           85  TONY STARK    85  ...  PRON  PER         him
# 47           85  TONY STARK    85  ...  PRON  PER         him
# 48           85  TONY STARK    85  ...  PROP  PER        Tony
# 49           85  TONY STARK    85  ...  PRON  PER         his
# 50           85  TONY STARK    85  ...  PRON  PER          he
# 51           85  TONY STARK    85  ...  PRON  PER         his
# 52           85  TONY STARK    85  ...  PROP  PER        Tony
# 53           85  TONY STARK    85  ...  PROP  PER        Tony
# 54           85  TONY STARK    85  ...  PROP  PER        Tony
# 55           85  TONY STARK    85  ...  PRON  PER         him
# 56           85  TONY STARK    85  ...  PROP  PER        Tony
# 57           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 58           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 59           85  TONY STARK    85  ...  PROP  PER        Tony
# 60           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 61           85  TONY STARK    85  ...  PROP  PER        Tony
# 62           85  TONY STARK    85  ...  PROP  PER        Tony
# 63           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 64           85  TONY STARK    85  ...  PROP  PER        Tony
# 65           85  TONY STARK    85  ...  PRON  PER          he
# 66           85  TONY STARK    85  ...  PRON  PER          he
# 67           85  TONY STARK    85  ...  PRON  PER          he
# 68           85  TONY STARK    85  ...  PRON  PER          he
# 69           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 70           85  TONY STARK    85  ...  PRON  PER          he
# 71           85  TONY STARK    85  ...  PRON  PER          He
# 72           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 73           85  TONY STARK    85  ...  PRON  PER         him
# 74           85  TONY STARK    85  ...  PRON  PER          he
# 75           85  TONY STARK    85  ...  PRON  PER          He
# 76           85  TONY STARK    85  ...  PRON  PER          he
# 77           85  TONY STARK    85  ...  PRON  PER          he
# 78           85  TONY STARK    85  ...  PRON  PER         you
# 79           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 80           85  TONY STARK    85  ...  PROP  PER        Tony
# 81           85  TONY STARK    85  ...  PRON  PER         you
# 82           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 83           85  TONY STARK    85  ...  PRON  PER         you
# 84           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 85           85  TONY STARK    85  ...  PRON  PER         you
# 86           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 87           85  TONY STARK    85  ...  PROP  PER        Tony
# 88           85  TONY STARK    85  ...  PRON  PER         you
# 89           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 90           85  TONY STARK    85  ...  PROP  PER        Tony
# 91           85  TONY STARK    85  ...  PROP  PER        Tony
# 92           85  TONY STARK    85  ...  PRON  PER         him
# 93           85  TONY STARK    85  ...  PRON  PER         him
# 94           85  TONY STARK    85  ...  PROP  PER        Tony
# 95           85  TONY STARK    85  ...  PROP  PER        Tony
# 96           85  TONY STARK    85  ...  PROP  PER        Tony
# 97           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 98           85  TONY STARK    85  ...  PROP  PER  TONY STARK
# 99           85  TONY STARK    85  ...  PROP  PER  TONY STARK
#
# [100 rows x 8 columns]

# %% [markdown]
# # Create Character Proximity Network Data

# %% [markdown]
# We want to make a network where characters have a connection, or edge, if they appear near each other in the text (within 100 token of one another). To make this measurement, we can use the "starting_tokens" where the characters first appear and substract them.
#
# First, we will make all the names and starting tokens into lists. Then we will zip them together.

# %%
names = entity_df['Name'].tolist()
start_tokens = entity_df['start_token'].tolist()

# %% [markdown]
# Then we will use `itertools` to make a combinations of all the characters and starting tokens.

# %%
import itertools

edge_list = []
threshold_distance = 15

# Make all possible combinations of characters and start tokens
for person, another_person in itertools.combinations(zip(names, start_tokens), 2):
    
    # Measure the distance between tokens
    distance = abs(person[1] - another_person[1])
    # If distance is smaller than 100
    if distance < threshold_distance:
        # and it's not the same person
        if person[0] != another_person[0]:
            # add the edge to the list
            edge_list.append((person[0], another_person[0]))

character_df = pd.DataFrame(Counter(edge_list).most_common(), columns=['character_pair', 'edge_weight'])
character_df['character1']=character_df['character_pair'].str[0]
character_df['character2']=character_df['character_pair'].str[1]

# %%
character_df[:50]
# Out:
#                       character_pair  ...        character2
# 0         (TONY STARK, STEVE ROGERS)  ...      STEVE ROGERS
# 1           (TONY STARK, SCOTT LANG)  ...        SCOTT LANG
# 2   (CLINT BARTON, NATASHA ROMANOFF)  ...  NATASHA ROMANOFF
# 3                (BRUCE, SCOTT LANG)  ...        SCOTT LANG
# 4               (TONY STARK, Pepper)  ...            Pepper
# 5         (STEVE ROGERS, SCOTT LANG)  ...        SCOTT LANG
# 6              (STEVE ROGERS, BRUCE)  ...             BRUCE
# 7             (STEVE ROGERS, THANOS)  ...            THANOS
# 8               (TONY STARK, THANOS)  ...            THANOS
# 9                      (BRUCE, THOR)  ...              THOR
# 10                  (Nebula, Gamora)  ...            Gamora
# 11                (TONY STARK, THOR)  ...              THOR
# 12                  (THANOS, Nebula)  ...            Nebula
# 13               (TONY STARK, Peter)  ...             Peter
# 14                    (THOR, ROCKET)  ...            ROCKET
# 15              (TONY STARK, Nebula)  ...            Nebula
# 16        (TONY STARK, MORGAN STARK)  ...      MORGAN STARK
# 17               (STEVE ROGERS, Sam)  ...               Sam
# 18                    (THOR, THANOS)  ...            THANOS
# 19        (TONY STARK, HOWARD STARK)  ...      HOWARD STARK
# 20              (TONY STARK, RHODEY)  ...            RHODEY
# 21                    (THOR, FRIGGA)  ...            FRIGGA
# 22               (TONY STARK, BRUCE)  ...             BRUCE
# 23           (THANOS, CAROL DANVERS)  ...     CAROL DANVERS
# 24  (STEVE ROGERS, NATASHA ROMANOFF)  ...  NATASHA ROMANOFF
# 25                      (THOR, KORG)  ...              KORG
# 26                     (THOR, Quill)  ...             Quill
# 27                  (Ronin, Akihiko)  ...           Akihiko
# 28              (CLINT BARTON, Lila)  ...              Lila
# 29            (CLINT BARTON, Nebula)  ...            Nebula
# 30                  (Nebula, RHODEY)  ...            RHODEY
# 31              (STEVE ROGERS, THOR)  ...              THOR
# 32                   (BRUCE, THANOS)  ...            THANOS
# 33                   (BRUCE, ROCKET)  ...            ROCKET
# 34                   (Peter, Gamora)  ...            Gamora
# 35     (STEVE ROGERS, CAROL DANVERS)  ...     CAROL DANVERS
# 36              (SCOTT LANG, RHODEY)  ...            RHODEY
# 37      (STEVE ROGERS, CLINT BARTON)  ...      CLINT BARTON
# 38                 (BRUCE, VALKYRIE)  ...          VALKYRIE
# 39            (STEVE ROGERS, RHODEY)  ...            RHODEY
# 40                       (Sam, BUCK)  ...              BUCK
# 41            (THANOS, CLINT BARTON)  ...      CLINT BARTON
# 42                  (THANOS, Gamora)  ...            Gamora
# 43           (STEVE ROGERS, Mjolnir)  ...           Mjolnir
# 44              (THOR, Stormbreaker)  ...      Stormbreaker
# 45                 (THANOS, Mjolnir)  ...           Mjolnir
# 46    (TONY STARK, ALEXANDER PIERCE)  ...  ALEXANDER PIERCE
# 47         (BRUCE, NATASHA ROMANOFF)  ...  NATASHA ROMANOFF
# 48    (SCOTT LANG, NATASHA ROMANOFF)  ...  NATASHA ROMANOFF
# 49          (CLINT BARTON, T'Challa)  ...          T'Challa
#
# [50 rows x 4 columns]

# %% [markdown]
# Write to CSV (where you can then download this data)

# %%
character_df.to_csv('EG-Character-Edge-List.csv', index=False)
